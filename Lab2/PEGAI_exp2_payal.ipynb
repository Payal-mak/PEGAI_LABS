# %%
# Name: Payal Makwana
# Er. No.: 92301733057

# %%
# !pip install -q google-generativeai

# %%
import google.generativeai as genai
# Out:
# /usr/local/lib/python3.12/dist-packages/google/colab/_import_hooks/_hook_injector.py:55: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   loader.exec_module(module)

# %%
import os
import google.generativeai as genai

API_KEY = os.getenv("GEMINI_API_KEY")

if not API_KEY:
    raise ValueError("Please set the GEMINI_API_KEY environment variable.")

genai.configure(api_key=API_KEY)

# %%
model = genai.GenerativeModel("gemini-2.5-flash")

# %%
prompt = """
You are an expert Data Cleaning Assistant.

Clean the following dataset.

Student_ID,Name,Age,City,CGPA
101,Hetansh,21,Rajkot,8.8
102,Om,,Ahmedabad,9.1
103,JC,19,,7.6
101,Bhavin,21,Rajkot,8.8

Tasks:

1. Remove duplicates
2. Fill missing values
3. Standardize city names
4. Return the cleaned table
"""

# %%
response = model.generate_content(prompt)

# %%
print(response.text)
# Out:
# Okay, I'll clean the dataset according to your instructions.
#
# Here's a breakdown of the cleaning process and the resulting cleaned table:
#
# ### Original Dataset:
# ```
# Student_ID,Name,Age,City,CGPA
# 101,Hetansh,21,Rajkot,8.8
# 102,Om,,Ahmedabad,9.1
# 103,JC,19,,7.6
# 101,Bhavin,21,Rajkot,8.8
# ```
#
# ---
#
# ### Cleaning Steps:
#
# **1. Remove Duplicates**
# *   **Analysis:** I've checked for rows that are identical across all columns.
#     *   `101,Hetansh,21,Rajkot,8.8`
#     *   `102,Om,,Ahmedabad,9.1`
#     *   `103,JC,19,,7.6`
#     *   `101,Bhavin,21,Rajkot,8.8`
# *   **Action:** There are no exact duplicate rows. While `Student_ID` 101 appears twice with different names (Hetansh and Bhavin), these are distinct records, not identical duplicates. This indicates a potential data integrity issue (two different students with the same ID), but per the instruction to "remove duplicates" (meaning identical rows), no rows are removed here.
#
# **2. Fill Missing Values**
# ...

# %%
prompt = """
You are an expert Data Cleaning Assistant.

Your task is to clean the following student dataset.

Dataset:

Student_ID,Name,Age,City,CGPA
101,Aryan,21,Rajkot,8.9
102,Riya,,Ahmedabad,9.1
103,Rahul,19,,7.8
101,Aryan,21,Rajkot,8.9
104,Neha,Twenty,Surat,8.4
105,Karan,22,rajkot,8.0
106,Priya,20,Ahmedabad,
107,,21,Vadodara,7.5

Tasks:
1. Remove duplicate records.
2. Fill missing values appropriately.
3. Convert Age to numeric values.
4. Standardize city names (e.g., Rajkot, Ahmedabad).
5. Fill missing CGPA if possible.
6. Return the cleaned dataset in a markdown table.
7. Explain each cleaning step performed.
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# Here's the cleaned student dataset and a detailed explanation of each cleaning step performed.
#
# ---
#
# ### Cleaned Dataset
#
# | Student_ID | Name    | Age | City      | CGPA |
# | :--------- | :------ | :-- | :-------- | :--- |
# | 101        | Aryan   | 21  | Rajkot    | 8.9  |
# | 102        | Riya    | N/A | Ahmedabad | 9.1  |
# | 103        | Rahul   | 19  | Unknown   | 7.8  |
# | 104        | Neha    | 20  | Surat     | 8.4  |
# | 105        | Karan   | 22  | Rajkot    | 8.0  |
# | 106        | Priya   | 20  | Ahmedabad | N/A  |
# | 107        | Unknown | 21  | Vadodara  | 7.5  |
#
# ---
#
# ### Explanation of Cleaning Steps
#
# **Original Dataset:**
#
# ```
# Student_ID,Name,Age,City,CGPA
# 101,Aryan,21,Rajkot,8.9
# 102,Riya,,Ahmedabad,9.1
# 103,Rahul,19,,7.8
# 101,Aryan,21,Rajkot,8.9
# 104,Neha,Twenty,Surat,8.4
# 105,Karan,22,rajkot,8.0
# 106,Priya,20,Ahmedabad,
# 107,,21,Vadodara,7.5
# ```
#
# ---
#
# #### 1. Remove Duplicate Records
#
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following dataset.

Dataset:

Student_ID,Name,Age,Gender,City,CGPA
101,Aryan,21,Male,Rajkot,8.9
102,Riya,,Female,Ahmedabad,9.1
103,Rahul,19,Male,,7.8
101,Aryan,21,Male,Rajkot,8.9
104,Neha,Twenty,Female,Surat,8.4
105,Karan,22,Male,rajkot,8.0
106,Priya,20,Female,Ahmedabad,
107,,21,Female,Vadodara,7.5

Perform the following data cleaning tasks:

1. Identify duplicate records and remove them.
2. Detect missing values and fill them using appropriate techniques.
3. Convert invalid data types into valid formats.
4. Standardize text values such as city names.
5. Correct inconsistent formatting.
6. Validate numerical values.
7. Ensure every record follows the same structure.
8. Explain every modification made.
9. Display the cleaned dataset as a Markdown table.
10. Finally provide a short summary of the cleaning process.

The response should contain the following sections:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I have thoroughly analyzed the provided dataset and identified several inconsistencies and missing values. My objective is to transform this raw data into a clean, consistent, and usable format.
#
# ---
#
# ### Problems Found
#
# The following data quality issues were identified in the dataset:
#
# 1.  **Duplicate Record:** The record for `Student_ID 101` (Aryan, 21, Male, Rajkot, 8.9) appears twice, which is redundant.
# 2.  **Missing Age:** For `Student_ID 102` (Riya), the `Age` field is empty.
# 3.  **Missing City:** For `Student_ID 103` (Rahul), the `City` field is empty.
# 4.  **Invalid Data Type (Age):** For `Student_ID 104` (Neha), the `Age` is recorded as "Twenty" (string) instead of a numerical integer.
# 5.  **Inconsistent Text Formatting (City):** For `Student_ID 105` (Karan), the `City` is "rajkot" (lowercase) instead of "Rajkot" (proper case).
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following employee payroll dataset.

Dataset:

Employee_ID,Name,Department,Salary,Experience,City
E101,Amit,IT,50000,5,Ahmedabad
E102,Priya,HR,,3,Surat
E103,Rahul,Finance,45000,,Rajkot
E104,Sneha,IT,52000,Five,Ahmedabad
E101,Amit,IT,50000,5,Ahmedabad
E105,Karan,,47000,2,Vadodara
E106,Riya,HR,-30000,4,Surat
E107,Neha,Finance,55000,6,rajkot

Perform the following tasks:

1. Remove duplicate records.
2. Handle missing values.
3. Correct invalid salary values.
4. Convert Experience into numeric values.
5. Standardize department names.
6. Standardize city names.
7. Validate salary values.
8. Return the cleaned dataset as a Markdown table.
9. Explain every cleaning step.
10. Give a short summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# ERROR:tornado.access:503 POST /v1beta/models/gemini-2.5-flash:generateContent?%24alt=json%3Benum-encoding%3Dint (::1) 32493.04ms
# As a professional Data Cleaning and Data Preprocessing Expert, I've analyzed the provided employee payroll dataset. Below is a detailed account of the problems found, the steps taken to clean the data, the resulting cleaned dataset, and a summary of the work.
#
# ---
#
# ### Problems Found
#
# 1.  **Duplicate Records:** One employee record (`E101, Amit, IT, 50000, 5, Ahmedabad`) was duplicated, leading to redundant data.
# 2.  **Missing Values:**
#     *   Salary for Employee `E102` was missing.
#     *   Experience for Employee `E103` was missing.
#     *   Department for Employee `E105` was missing.
# 3.  **Invalid Salary Values:** Employee `E106` had a negative salary (`-30000`), which is logically incorrect for payroll.
# 4.  **Inconsistent Data Types (Experience):** Employee `E104` had 'Experience' as a string ("Five") instead of a numeric value.
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following banking transaction dataset.

Dataset:

Transaction_ID,Customer_Name,Amount,Transaction_Date,Transaction_Type,Branch
T101,Rahul,5000,2024/01/10,Deposit,Rajkot
T102,Priya,,2024-01-11,Withdrawal,Ahmedabad
T103,Amit,-1000,10-01-2024,Deposit,Surat
T104,Neha,2500,,Transfer,Vadodara
T101,Rahul,5000,2024/01/10,Deposit,Rajkot
T105,,3200,2024-01-15,Deposit,rajkot
T106,Riya,4100,15-Jan-2024,Withdrawl,Ahmedabad

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid transaction amounts.
4. Standardize date format (YYYY-MM-DD).
5. Correct spelling mistakes.
6. Standardize branch names.
7. Return the cleaned dataset in Markdown table format.
8. Explain all modifications.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly reviewed and cleaned the provided banking transaction dataset. Below is a detailed report of the problems found, the cleaning steps taken, the resulting cleaned dataset, and a summary.
#
# ---
#
# ### Problems Found
#
# Upon initial inspection of the dataset, the following issues were identified:
#
# 1.  **Duplicate Records:** One transaction record was an exact duplicate.
# 2.  **Missing Values:**
#     *   A `Transaction_ID` (T102) was missing its `Amount`.
#     *   A `Transaction_ID` (T104) was missing its `Transaction_Date`.
#     *   A `Transaction_ID` (T105) was missing its `Customer_Name`.
# 3.  **Invalid Transaction Amounts:** One transaction (`T103`) showed a negative amount for a `Deposit` transaction, which is logically incorrect.
# 4.  **Inconsistent Date Formats:** Dates were represented in multiple formats (`YYYY/MM/DD`, `DD-MM-YYYY`, `DD-Mon-YYYY`) instead of a single standard (`YYYY-MM-DD`).
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following hospital patient dataset.

Dataset:

Patient_ID,Name,Age,Gender,Blood_Group,Disease,Admission_Date,Discharge_Date,City
P101,Rahul,25,Male,B+,Fever,2024-01-10,2024-01-13,Rajkot
P102,Priya,,Female,O+,Diabetes,10/02/2024,15/02/2024,Ahmedabad
P103,Amit,-5,Male,A+,Cold,2024/03/12,2024/03/15,Surat
P104,Neha,Twenty Eight,Female,AB+,Covid,2024-04-01,,Vadodara
P101,Rahul,25,Male,B+,Fever,2024-01-10,2024-01-13,Rajkot
P105,Karan,40,,O-,Cancer,2024-05-01,2024-05-10,rajkot
P106,Riya,30,Female,,Asthma,01-06-2024,05-06-2024,
P107,,45,Male,A+,Heart Disease,2024-07-10,2024-07-20,Ahmedabad

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Convert Age into numeric values.
4. Correct invalid age values.
5. Standardize Gender values.
6. Standardize Blood Group values.
7. Standardize City names.
8. Convert all dates to YYYY-MM-DD format.
9. Return the cleaned dataset as a Markdown table.
10. Explain every cleaning step.
11. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I have thoroughly analyzed and cleaned the provided hospital patient dataset. The goal was to ensure data quality, consistency, and usability for further analysis.
#
# ---
#
# ### Problems Found
#
# During the initial assessment, the following data quality issues were identified:
#
# 1.  **Duplicate Records:** One patient record (P101) was duplicated, leading to redundant information.
# 2.  **Missing Values:**
#     *   `Age`: Missing for Patient P102.
#     *   `Name`: Missing for Patient P107.
#     *   `Gender`: Missing for Patient P105.
#     *   `Blood_Group`: Missing for Patient P106.
#     *   `Discharge_Date`: Missing for Patient P104.
#     *   `City`: Missing for Patient P106.
# 3.  **Invalid Age Values:**
#     *   `Age`: Patient P103 had a negative age (-5).
#     *   `Age`: Patient P104 had age as a string ("Twenty Eight") instead of a numeric value.
# 4.  **Inconsistent Data Formats:**
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean and preprocess the following e-commerce orders dataset.

Dataset:

Order_ID,Customer_Name,Product,Quantity,Price,Order_Date,Payment_Mode,City
O101,Rahul,Laptop,1,55000,2024-01-10,Credit Card,Rajkot
O102,Priya,Mobile,,25000,10/01/2024,UPI,Ahmedabad
O103,Amit,Headphones,-2,2500,2024/02/15,Cash,Surat
O104,Neha,Keyboard,2,,2024-03-12,Debit Card,Vadodara
O101,Rahul,Laptop,1,55000,2024-01-10,Credit Card,Rajkot
O105,Karan,Mouse,3,800,15-04-2024,upi,rajkot
O106,Riya,,1,1200,2024-05-20,COD,
O107,,Monitor,1,18000,2024-06-15,Credit Card,Ahmedabad

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid quantity values.
4. Correct missing prices.
5. Standardize payment mode names.
6. Standardize city names.
7. Convert dates to YYYY-MM-DD format.
8. Return the cleaned dataset as a Markdown table.
9. Explain all cleaning steps.
10. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I have analyzed the provided e-commerce orders dataset and performed the requested cleaning and preprocessing tasks.
#
# ---
#
# ### Problems Found
#
# Upon initial inspection of the dataset, several data quality issues were identified:
#
# *   **Duplicate Records:** An identical order (Order_ID O101) appeared twice, leading to redundant data.
# *   **Missing Values:**
#     *   `Customer_Name` was missing for one order (O107).
#     *   `Product` was missing for one order (O106).
#     *   `Quantity` was missing for one order (O102).
#     *   `Price` was missing for one order (O104).
#     *   `City` was missing for one order (O106).
# *   **Invalid Quantity Values:** A negative quantity (`-2`) was present for one order (O103), which is logically impossible for an ordered item.
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Your task is to clean the following weather dataset.

Dataset:

Record_ID,City,Temperature,Humidity,Rainfall,Date
W101,Rajkot,35,65,0,2024-01-10
W102,Ahmedabad,,70,5,10/01/2024
W103,Surat,-120,80,12,2024/02/12
W104,Vadodara,31,,2,15-03-2024
W101,Rajkot,35,65,0,2024-01-10
W105,rajkot,33,60,,2024-04-15
W106,,29,55,1,2024-05-12

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct impossible temperature values.
4. Correct humidity values.
5. Standardize city names.
6. Standardize date format.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)

print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly reviewed the provided weather dataset. Below is a detailed account of the problems identified, the cleaning steps performed, the resulting cleaned dataset, and a summary.
#
# ---
#
# ### Problems Found
#
# 1.  **Duplicate Records:** One entire record for `Record_ID W101` was duplicated, leading to redundant data.
# 2.  **Missing Values:**
#     *   The `Temperature` field was empty for `Record_ID W102` (Ahmedabad).
#     *   The `Humidity` field was empty for `Record_ID W104` (Vadodara).
#     *   The `Rainfall` field was empty for `Record_ID W105` (rajkot).
#     *   The `City` field was empty for `Record_ID W106`.
# 3.  **Impossible Temperature Values:** `Record_ID W103` (Surat) had a `Temperature` of `-120`, which is an unrealistic and physically impossible value for surface weather conditions.
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean the following telecom customer dataset.

Dataset:

Customer_ID,Name,Mobile_No,Plan,Monthly_Bill,City
C101,Rahul,9876543210,Premium,799,Rajkot
C102,Priya,,Basic,399,Ahmedabad
C103,Amit,9876543210,Premium,799,Rajkot
C104,Neha,9123456789,,599,Surat
C105,Karan,9876512345,Standard,-200,Vadodara
C106,Riya,912345678,Premium,899,rajkot
C107,,9988776655,Basic,399,
C101,Rahul,9876543210,Premium,799,Rajkot

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Validate mobile numbers (10 digits).
4. Correct invalid monthly bill values.
5. Standardize city names.
6. Standardize plan names.
7. Return the cleaned dataset in Markdown table format.
8. Explain every cleaning step.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I have thoroughly analyzed the provided telecom customer dataset. Below are the identified problems, the cleaning steps taken, the resulting cleaned dataset, and a summary of the process.
#
# ---
#
# ### Problems Found
#
# Upon reviewing the dataset, the following data quality issues were identified:
#
# *   **Duplicate Records:** One exact duplicate record was found for Customer ID `C101`.
# *   **Missing Values:**
#     *   `Mobile_No` is missing for Customer `C102` (Priya).
#     *   `Plan` is missing for Customer `C104` (Neha).
#     *   `Name` is missing for Customer `C107`.
#     *   `City` is missing for Customer `C107`.
# *   **Invalid Mobile Numbers:**
#     *   `Mobile_No` for `C102` is missing, hence invalid.
#     *   `Mobile_No` for `C106` (Riya) has only 9 digits, violating the 10-digit standard.
# *   **Invalid Monthly Bill Values:**
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following hotel booking dataset.

Dataset:

Booking_ID,Guest_Name,Room_Type,Check_In,Check_Out,Amount,City
B101,Rahul,Deluxe,2024-01-10,2024-01-15,8000,Rajkot
B102,Priya,,10/02/2024,15/02/2024,6500,Ahmedabad
B103,Amit,Standard,2024/03/12,,5000,Surat
B104,Neha,Suite,2024-04-01,2024-04-05,-9000,Vadodara
B105,Karan,Deluxe,01-05-2024,05-05-2024,8500,rajkot
B106,,Standard,2024-06-01,2024-06-03,4500,
B101,Rahul,Deluxe,2024-01-10,2024-01-15,8000,Rajkot

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid amount values.
4. Standardize room type names.
5. Convert all dates to YYYY-MM-DD format.
6. Standardize city names.
7. Return the cleaned dataset as a Markdown table.
8. Explain every cleaning step.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly analyzed the provided hotel booking dataset and performed the requested cleaning operations to enhance its quality and consistency.
#
# ### Problems Found
#
# The initial dataset presented several data quality issues:
#
# 1.  **Duplicate Records:** One identical booking record (`B101, Rahul`) was present twice.
# 2.  **Missing Values:**
#     *   `Room_Type` was missing for Booking ID `B102`.
#     *   `Guest_Name` was missing for Booking ID `B106`.
#     *   `Check_Out` date was missing for Booking ID `B103`.
#     *   `City` was missing for Booking ID `B106`.
# 3.  **Invalid Data:** The `Amount` for Booking ID `B104` was a negative value (`-9000`), which is logically incorrect for a booking amount.
# 4.  **Inconsistent Data Formats:**
#     *   **Date Formats:** `Check_In` and `Check_Out` dates were in various formats (e.g., `YYYY-MM-DD`, `DD/MM/YYYY`, `YYYY/MM/DD`, `DD-MM-YYYY`).
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following product inventory dataset.

Dataset:

Product_ID,Product_Name,Category,Stock,Price,Supplier
P101,Laptop,Electronics,20,55000,ABC Pvt Ltd
P102,Mouse,Electronics,,800,XYZ Ltd
P103,Keyboard,Electronics,-5,1200,Tech World
P104,Monitor,,15,,ABC Pvt Ltd
P105,Printer,Electronics,10,15000,
P106,Scanner,Electronics,12,14000,abc pvt ltd
P101,Laptop,Electronics,20,55000,ABC Pvt Ltd

Perform the following tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid stock values.
4. Correct missing prices.
5. Standardize supplier names.
6. Standardize category names.
7. Return the cleaned dataset as a Markdown table.
8. Explain every cleaning step.
9. Provide a summary.

The response should contain:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I've thoroughly reviewed your product inventory dataset. I've identified several issues that hinder data quality and consistency. Below is a detailed breakdown of the problems, the cleaning steps taken, the resulting cleaned dataset, and a summary.
#
# ---
#
# ### Problems Found
#
# 1.  **Duplicate Records:** An exact duplicate entry for `P101, Laptop` was present.
# 2.  **Missing Values:**
#     *   `P102, Mouse`: Missing `Stock` value.
#     *   `P104, Monitor`: Missing `Category` value and `Price` value.
#     *   `P105, Printer`: Missing `Supplier` name.
# 3.  **Invalid Stock Values:** `P103, Keyboard` had a negative `Stock` value (`-5`), which is illogical for inventory.
# 4.  **Inconsistent Supplier Names:** `ABC Pvt Ltd` and `abc pvt ltd` refer to the same entity but have different casing.
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean the following IoT sensor dataset.

Dataset:

Sensor_ID,Location,Temperature,Humidity,Battery_Level,Timestamp
S101,Lab1,28,60,95,2024-01-10 10:00
S102,Lab2,,65,90,10/01/2024 11:00
S103,Lab3,-150,70,88,2024/01/12 09:00
S104,,30,,85,15-01-2024 08:00
S101,Lab1,28,60,95,2024-01-10 10:00
S105,Lab5,32,55,-10,2024-02-01 12:00
S106,Lab6,29,58,80,

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid temperature values.
4. Correct invalid battery values.
5. Standardize timestamps.
6. Standardize location names.
7. Return cleaned dataset in Markdown table.
8. Explain every cleaning step.
9. Give summary.

Response format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I have analyzed the provided IoT sensor dataset and identified several issues that need to be addressed to ensure data quality and consistency.
#
# ### • Problems Found
#
# 1.  **Duplicate Records:** One identical record (S101) is present twice.
# 2.  **Missing Values:**
#     *   `Temperature` is missing for S102.
#     *   `Location` is missing for S104.
#     *   `Humidity` is missing for S104.
#     *   `Timestamp` is missing for S106.
# 3.  **Invalid Temperature Values:**
#     *   S103 has a `Temperature` of -150, which is physically implausible for typical lab environments.
# 4.  **Invalid Battery Values:**
#     *   S105 has a `Battery_Level` of -10, which is an invalid negative value (battery levels are typically 0-100%).
# 5.  **Inconsistent Timestamp Formats:** Timestamps are in various formats (`YYYY-MM-DD HH:MM`, `DD/MM/YYYY HH:MM`, `YYYY/MM/DD HH:MM`, `DD-MM-YYYY HH:MM`).
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following library dataset.

Dataset:

Book_ID,Book_Name,Author,Category,Price,Available
B101,Python Basics,John Smith,Programming,450,Yes
B102,Data Science,,Programming,650,Yes
B103,Machine Learning,Andrew Ng,AI,-900,No
B104,Deep Learning,Ian Goodfellow,,700,Yes
B101,Python Basics,John Smith,Programming,450,Yes
B105,C Programming,Dennis Ritchie,Programming,,yes
B106,,Robert Martin,Software,550,

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid prices.
4. Standardize category names.
5. Standardize Available values.
6. Return cleaned dataset in Markdown.
7. Explain every cleaning step.
8. Provide summary.

Response format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly analyzed the provided library dataset and identified several issues that hinder its quality and consistency. Below is a detailed report of the problems found, the cleaning steps taken, the resulting cleaned dataset, and a summary of the work.
#
# ---
#
# •   **Problems Found**
#
# The following data quality issues were identified in the dataset:
#
# 1.  **Duplicate Records:** The entry for "Python Basics" (Book_ID B101) appears twice.
# 2.  **Missing Values:**
#     *   `Author` is missing for "Data Science" (B102).
#     *   `Category` is missing for "Deep Learning" (B104) and "C Programming" (B105).
#     *   `Price` is missing for "C Programming" (B105).
#     *   `Book_Name` is missing for Book_ID B106.
#     *   `Available` status is missing for Book_ID B106.
# 3.  **Invalid Prices:** The `Price` for "Machine Learning" (B103) is negative (-900), which is illogical for a book price.
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following university admission dataset.

Dataset:

Student_ID,Name,Course,Percentage,City,Admission_Date
U101,Rahul,B.Tech ICT,89,Rajkot,2024-06-01
U102,Priya,BCA,,Ahmedabad,01/06/2024
U103,Amit,B.Tech CSE,-70,Surat,2024/06/02
U104,Neha,,92,Vadodara,03-06-2024
U101,Rahul,B.Tech ICT,89,Rajkot,2024-06-01
U105,Karan,BBA,75,rajkot,
U106,,MBA,81,,2024-06-10

Tasks:

1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid percentages.
4. Standardize course names.
5. Standardize city names.
6. Convert dates to YYYY-MM-DD.
7. Return cleaned dataset in Markdown.
8. Explain every cleaning step.
9. Provide summary.

Response format:

• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly analyzed and cleaned the provided university admission dataset. Below is a detailed report of the findings, cleaning steps, the cleaned dataset, and a summary.
#
# ---
#
# ### • Problems Found
#
# During the initial assessment, the following data quality issues were identified in the dataset:
#
# 1.  **Duplicate Records:** One exact duplicate record was present for Student ID `U101`.
# 2.  **Missing Values:**
#     *   `Percentage` was missing for Student ID `U102`.
#     *   `Course` was missing for Student ID `U104`.
#     *   `Admission_Date` was missing for Student ID `U105`.
#     *   `Name` and `City` were missing for Student ID `U106`.
# 3.  **Invalid Percentages:** Student ID `U103` had a negative percentage (`-70`), which is logically invalid.
# 4.  **Inconsistent City Names:** The city 'Rajkot' appeared in inconsistent casing (`Rajkot` vs `rajkot`).
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Clean the following vehicle registration dataset.

Dataset:

Vehicle_ID,Owner_Name,Vehicle_Type,Registration_Date,Insurance_Status,City
V101,Rahul,Car,2024-01-10,Active,Rajkot
V102,Priya,Bike,10/02/2024,Expired,Ahmedabad
V103,Amit,Truck,,Active,Surat
V104,Neha,Car,2024/03/12,,Vadodara
V101,Rahul,Car,2024-01-10,Active,Rajkot
V105,Karan,,15-04-2024,Expired,rajkot
V106,,Bike,2024-05-20,Active,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Standardize vehicle type names.
4. Standardize city names.
5. Standardize insurance status.
6. Convert dates into YYYY-MM-DD.
7. Return cleaned dataset in Markdown table.
8. Explain every cleaning step.
9. Give summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I have analyzed the provided vehicle registration dataset. Below are the identified issues, the steps taken to clean the data, the resulting cleaned dataset, and a summary of the work.
#
# ---
#
# ### Problems Found
#
# 1.  **Duplicate Records:** The record for `Vehicle_ID` V101 (Rahul, Car, 2024-01-10, Active, Rajkot) appeared twice, indicating a redundant entry.
# 2.  **Missing Values:**
#     *   `Registration_Date`: Missing for `Vehicle_ID` V103.
#     *   `Insurance_Status`: Missing for `Vehicle_ID` V104.
#     *   `Vehicle_Type`: Missing for `Vehicle_ID` V105.
#     *   `Owner_Name`: Missing for `Vehicle_ID` V106.
#     *   `City`: Missing for `Vehicle_ID` V106.
# 3.  **Inconsistent Date Formats:** The `Registration_Date` column contained various formats:
#     *   `YYYY-MM-DD` (e.g., `2024-01-10`)
#     *   `DD/MM/YYYY` (e.g., `10/02/2024`)
#     *   `YYYY/MM/DD` (e.g., `2024/03/12`)
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following sales dataset.

Dataset:

Sale_ID,Salesperson,Product,Quantity,Price,Sale_Date,City
S101,Rahul,Laptop,2,55000,2024-01-10,Rajkot
S102,Priya,Mouse,,800,10/01/2024,Ahmedabad
S103,Amit,Keyboard,-3,1200,2024/02/15,Surat
S104,Neha,Monitor,1,,2024-03-12,Vadodara
S101,Rahul,Laptop,2,55000,2024-01-10,Rajkot
S105,Karan,Printer,1,15000,15-04-2024,rajkot
S106,,Scanner,2,14000,,Ahmedabad

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid quantity.
4. Fill missing price.
5. Standardize city names.
6. Convert dates to YYYY-MM-DD.
7. Return cleaned dataset.
8. Explain every cleaning step.
9. Give summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly analyzed and cleaned the provided sales dataset.
#
# ### Problems Found
#
# 1.  **Duplicate Records:** One exact duplicate record was found for `Sale_ID` S101.
# 2.  **Missing Values:**
#     *   `Quantity` was missing for `Sale_ID` S102.
#     *   `Price` was missing for `Sale_ID` S104.
#     *   `Salesperson` was missing for `Sale_ID` S106.
#     *   `Sale_Date` was missing for `Sale_ID` S106.
# 3.  **Invalid Quantity:** An invalid negative quantity (`-3`) was present for `Sale_ID` S103.
# 4.  **Inconsistent City Names:** City names had inconsistent casing (e.g., "rajkot" instead of "Rajkot").
# 5.  **Inconsistent Date Formats:** `Sale_Date` entries were in various formats (e.g., `DD/MM/YYYY`, `YYYY/MM/DD`, `DD-MM-YYYY`), requiring standardization.
#
# ### Cleaning Steps
#
# 1.  **Remove Duplicate Records:**
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following customer feedback dataset.

Dataset:

Feedback_ID,Customer_Name,Rating,Feedback,Product
F101,Rahul,5,Excellent,Laptop
F102,Priya,,Good,Mouse
F103,Amit,6,Very Good,Keyboard
F104,Neha,4,,Monitor
F101,Rahul,5,Excellent,Laptop
F105,Karan,3,Average,
F106,,2,Poor,Printer

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid ratings.
4. Standardize feedback text.
5. Fill missing product names.
6. Return cleaned dataset.
7. Explain every cleaning step.
8. Give summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly analyzed the provided customer feedback dataset. Here's a breakdown of the identified problems, the cleaning steps performed, the resulting cleaned dataset, and a summary of the work.
#
# ---
#
# ### • Problems Found
#
# 1.  **Duplicate Record:** One identical record was found for `Feedback_ID F101`.
# 2.  **Missing Values:**
#     *   `Rating` was missing for `Feedback_ID F102`.
#     *   `Feedback` text was missing for `Feedback_ID F104`.
#     *   `Product` name was missing for `Feedback_ID F105`.
#     *   `Customer_Name` was missing for `Feedback_ID F106`.
# 3.  **Invalid Rating:** An invalid `Rating` of '6' was present for `Feedback_ID F103`, assuming a standard 1-5 rating scale.
# 4.  **Inconsistent Feedback Text (Potential):** While current feedback text is mostly capitalized, explicit standardization (e.g., consistent casing, trimming whitespace) ensures uniformity for future data and robustness.
#
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following restaurant order dataset.

Dataset:

Order_ID,Customer_Name,Food_Item,Quantity,Amount,Order_Date
R101,Rahul,Pizza,2,500,2024-01-10
R102,Priya,Burger,,200,10/02/2024
R103,Amit,Pasta,-1,300,2024/03/12
R104,Neha,,3,,15-04-2024
R101,Rahul,Pizza,2,500,2024-01-10
R105,Karan,Sandwich,1,150,
R106,,Fries,2,180,2024-05-20

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid quantity.
4. Fill missing amount.
5. Convert dates into YYYY-MM-DD.
6. Return cleaned dataset.
7. Explain every cleaning step.
8. Give summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# • Problems Found
# 1.  **Duplicate Records:** The record for Order_ID 'R101' (`R101,Rahul,Pizza,2,500,2024-01-10`) appeared twice.
# 2.  **Missing Values:**
#     *   'Quantity' was missing for Order_ID 'R102'.
#     *   'Food_Item' was missing for Order_ID 'R104'.
#     *   'Amount' was missing for Order_ID 'R104'.
#     *   'Order_Date' was missing for Order_ID 'R105'.
#     *   'Customer_Name' was missing for Order_ID 'R106'.
# 3.  **Invalid Quantity:** Quantity was '-1' (negative) for Order_ID 'R103', which is illogical for an order quantity.
# 4.  **Inconsistent Date Formats:** Dates were in various formats: 'YYYY-MM-DD' (R101), 'DD/MM/YYYY' (R102), 'YYYY/MM/DD' (R103), and 'DD-MM-YYYY' (R104).
#
# • Cleaning Steps
#
# 1.  **Remove Duplicate Records:**
#     *   The dataset was scanned for identical rows. The second occurrence of `R101,Rahul,Pizza,2,500,2024-01-10` was identified as a duplicate and removed. This ensures each order is unique.
#
# 2.  **Fill Missing Values:**
# ...

# %%
prompt = """
You are a professional Data Cleaning and Data Preprocessing Expert.

Your task is to clean the following airline booking dataset.

Dataset:

Booking_ID,Passenger_Name,Flight_No,Departure_Date,Seat_No,Fare,Status
A101,Rahul,AI201,2024-07-10,12A,5500,Confirmed
A102,Priya,AI202,10/07/2024,15B,,Confirmed
A103,Amit,AI203,2024/07/12,18C,-4000,Cancelled
A104,Neha,AI204,15-07-2024,,6200,confirmed
A101,Rahul,AI201,2024-07-10,12A,5500,Confirmed
A105,Karan,AI205,,20D,7000,
A106,,AI206,2024-07-20,25A,8000,Pending

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid fare values.
4. Standardize booking status.
5. Convert dates to YYYY-MM-DD.
6. Validate seat numbers.
7. Return cleaned dataset in Markdown.
8. Explain every cleaning step.
9. Give summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning and Data Preprocessing Expert, I've analyzed the provided airline booking dataset to identify inconsistencies, missing information, and erroneous entries. My goal is to transform this raw data into a clean, standardized, and reliable format for further analysis.
#
# ---
#
# ### Problems Found
#
# Upon initial review of the dataset, the following data quality issues were identified:
#
# 1.  **Duplicate Records**: One booking record (`A101`) was duplicated, leading to redundant data.
# 2.  **Missing Values**:
#     *   `Fare` was missing for `Booking_ID A102`.
#     *   `Seat_No` was missing for `Booking_ID A104`.
#     *   `Departure_Date` was missing for `Booking_ID A105`.
#     *   `Status` was missing for `Booking_ID A105`.
#     *   `Passenger_Name` was missing for `Booking_ID A106`.
# 3.  **Invalid Fare Values**:
#     *   `Fare` for `Booking_ID A103` was negative (`-4000`), which is logically incorrect for a booking fare.
# ...

# %%
prompt = """
You are a professional Data Cleaning Expert.

Clean the following manufacturing dataset.

Dataset:

Machine_ID,Machine_Name,Production_Units,Defective_Units,Shift,Factory
M101,Cutter,500,12,Morning,Rajkot
M102,Welder,,5,Evening,Ahmedabad
M103,Assembler,-250,8,Night,Surat
M104,Painter,600,,Morning,Vadodara
M101,Cutter,500,12,Morning,Rajkot
M105,Driller,450,-2,,rajkot
M106,,520,6,Evening,

Tasks:
1. Remove duplicate records.
2. Fill missing values.
3. Correct invalid production values.
4. Correct invalid defective units.
5. Standardize shift names.
6. Standardize factory names.
7. Return cleaned dataset in Markdown.
8. Explain every cleaning step.
9. Provide summary.

Response Format:
• Problems Found
• Cleaning Steps
• Cleaned Dataset
• Summary
"""

response = model.generate_content(prompt)
print(response.text)
# Out:
# As a professional Data Cleaning Expert, I have thoroughly analyzed and cleaned the provided manufacturing dataset. The cleaning process involved identifying and addressing various data quality issues to ensure the dataset is accurate, consistent, and ready for analysis.
#
# ---
#
# ### Problems Found
#
# 1.  **Duplicate Records:** One exact duplicate entry for `Machine_ID` M101 was present.
# 2.  **Missing Values:**
#     *   `Production_Units` was missing for `Machine_ID` M102.
#     *   `Defective_Units` was missing for `Machine_ID` M104.
#     *   `Shift` was missing for `Machine_ID` M105.
#     *   `Machine_Name` was missing for `Machine_ID` M106.
#     *   `Factory` was missing for `Machine_ID` M106.
# 3.  **Invalid Production Values:** `Production_Units` for `Machine_ID` M103 was negative (-250), which is logically impossible for physical production.
# ...
